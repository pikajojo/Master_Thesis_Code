# %%
import xarray as xr
from scipy.interpolate import griddata
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ### Prepare training set

# %%
file_path = "/Users/wangy/Documents/MACS/Thesis"
training_set_2015 = pd.read_csv(f"{file_path}/train_set/train_set_3_cities_2015.csv", index_col=0)
training_set_2016 = pd.read_csv(f"{file_path}/train_set/train_set_3_cities_2016.csv", index_col=0)

# %%
train_set_all = pd.concat([training_set_2015, training_set_2016], ignore_index=True)
print(train_set_all)
# Out:
#                         time          y         x        tas      Coast.nc  \
# 0                 2015-07-01  51.332417  4.513800  20.664545  17846.568359
# 1                 2015-07-01  51.336610  4.264203  19.721277   1818.640032
# 2                 2015-07-01  51.212650  4.515183  22.342126  23820.942030
# 3                 2015-07-01  51.311340  4.227067  20.765131   4500.000000
# 4                 2015-07-01  51.312443  4.285940  21.813562   4743.416504
# ...                      ...        ...       ...        ...           ...
# 4655995  2016-07-10 23:00:00  51.124294  3.660715  18.751581  24698.177734
# 4655996  2016-07-10 23:00:00  51.065052  3.551365  18.089471  33615.472656
# 4655997  2016-07-10 23:00:00  51.119267  3.767546  19.199121  23537.205078
# 4655998  2016-07-10 23:00:00  51.140090  3.685806  18.473291  22610.837891
# 4655999  2016-07-10 23:00:00  51.134712  3.837187  18.659509  21503.317721
#
#          LCZcorine_UrbClim_2015_01_v1.0.nc  height.nc  \
# 0                                     21.0   0.013173
# 1                                     43.0   0.000000
# 2                                      3.0   3.595983
# 3                                     12.0   0.000000
# 4                                     37.0   0.009319
# ...                                    ...        ...
# 4655995                               20.0   0.273453
# 4655996                               20.0   0.000000
# 4655997                                5.0   4.883322
# 4655998                               20.0   0.180466
# 4655999                               20.0   0.282049
#
#          imperv_UrbClim_2015_01_v1.0.nc  LCZ_UrbClim_2015_01_v1.0.nc  \
# 0                              0.000000                         11.0
# 1                              0.000000                         17.0
# 2                             80.113107                          4.0
# 3                              0.000000                         14.0
# 4                              1.138197                         14.0
# ...                                 ...                          ...
# 4655995                       13.208849                          6.0
# 4655996                        0.000000                         14.0
# 4655997                       75.274131                          8.0
# 4655998                        7.438143                         14.0
# 4655999                       10.746958                         14.0
#
#          population.nc  ...       cape         kx           ssr  \
# 0             0.239407  ...   0.000000  13.333500  2.328306e-10
# 1             0.000000  ...   0.000000  14.793607  2.328306e-10
# 2            37.861669  ...   0.000000  12.925625  2.328306e-10
# 3             0.000000  ...   0.000000  14.924988  2.328306e-10
# 4             0.144738  ...   0.000000  14.592812  2.328306e-10
# ...                ...  ...        ...        ...           ...
# 4655995       6.488735  ...  80.165167  16.468732  0.000000e+00
# 4655996       0.000000  ...  75.804965  16.249521  0.000000e+00
# 4655997       4.423150  ...  78.752825  16.738197  0.000000e+00
# 4655998       3.706859  ...  81.032201  16.493911  0.000000e+00
# 4655999       0.592821  ...  73.743150  16.713719  0.000000e+00
#
#                    str             sp           sshf       tcc        tcw  \
# 0       -261182.029065  101673.279369  185846.541624  0.004802  22.257494
# 1       -254322.323986  101703.518292  176471.302899  0.005223  22.716708
# 2       -261638.229069  101641.178035  185178.451433  0.000000  21.983525
# 3       -253723.925018  101700.773078  177339.575796  0.003699  22.670759
# 4       -255032.973607  101696.280704  178209.356063  0.003766  22.606139
# ...                ...            ...            ...       ...        ...
# 4655995  -39914.942135  100838.283410   23232.369094  1.000000  30.687755
# 4655996  -38561.989466  100787.049857   23875.428766  1.000000  30.491040
# 4655997  -40745.837890  100838.109658   22056.675060  1.000000  31.155532
# 4655998  -40356.376250  100851.483535   23175.909148  1.000000  30.716805
# 4655999  -43026.681835  100847.624026   29005.211549  1.000000  31.346064
#
#                    tp  t2m_corrected
# 0       -1.734723e-18      20.167857
# 1       -1.734723e-18      20.217564
# 2       -1.734723e-18      20.303346
# 3       -1.734723e-18      20.185793
# 4       -1.734723e-18      20.199558
# ...               ...            ...
# 4655995  0.000000e+00      18.102859
# 4655996  0.000000e+00      17.935552
# 4655997  2.386022e-08      18.289792
# 4655998  0.000000e+00      18.141813
# 4655999  1.185614e-07      18.428134
#
# [4656000 rows x 28 columns]

# %%
# delete all the NaN value here
train_set_all.dropna(inplace=True)
train_set_all.reset_index(drop=True, inplace=True)

y_train = pd.DataFrame()
# Calculate the residue
y_train['residue'] = train_set_all['tas'] - train_set_all['t2m_corrected']
X_train = train_set_all.drop(columns=['x','y','time','tas','hour'])

# %% [markdown]
# ### Prepare testing set

# %%
def add_time_feature(all_variables):
    all_variables['time'] = pd.to_datetime(all_variables['time'], format='mixed')
    # Extract the hour of the day
    all_variables['hour'] = all_variables['time'].dt.hour
    # Convert time features using sin and cos
    all_variables['hour_sin'] = np.sin(2 * np.pi * all_variables['hour'] / 24)
    all_variables['hour_cos'] = np.cos(2 * np.pi * all_variables['hour'] / 24)

# %%
def standardize_columns(columns):
    return [col.replace('_Brussels', '').replace('_Antwerp', '').replace('_Ghent', '').replace('_Charleroi', '') for col in columns]

# %%
urbclim_and_feature = pd.read_csv('/Users/wangy/Documents/MACS/Thesis/Urbclim_and_feature/Brussels_urbclim_and_features_2017_07_01to03.csv')
era5 = pd.read_csv('/Users/wangy/Documents/MACS/Thesis/ERA5_variables/Brussels/ERA5_2017_07_01to03_Brussels_Corrected_v1.csv')

urbclim_and_feature = urbclim_and_feature.drop(columns=[ 'Unnamed: 0'])
era5_new = era5.drop(columns=['x','y','time','Unnamed: 0','t2m'])
test_set = pd.concat([urbclim_and_feature,era5_new], axis=1)
add_time_feature(test_set)

# Adjust the column order of test set
test_set.columns = standardize_columns(test_set.columns)
base_columns = train_set_all.columns
test_set = test_set[base_columns]

# %%
# test_set = test_set.drop(columns = {"AHF.nc","elevation_UrbClim_2015_01_v1.0.nc"})

# delete all the NaN value here
test_set.dropna(inplace=True)
test_set.reset_index(drop=True, inplace=True)

# %%
y_test = pd.DataFrame()
# Calculate the residue
y_test['residue'] = test_set['tas'] - test_set['t2m_corrected']
X_test = test_set.drop(columns=['x','y','time','tas','hour'])

print(X_test.columns)
# Out:
# Index(['Coast.nc', 'LCZcorine_UrbClim_2015_01_v1.0.nc', 'height.nc',
#        'imperv_UrbClim_2015_01_v1.0.nc', 'LCZ_UrbClim_2015_01_v1.0.nc',
#        'population.nc', 'surface.nc', 'volume.nc', 'hour_sin', 'hour_cos',
#        'u10', 'v10', 'blh', 'cape', 'kx', 'ssr', 'str', 'sp', 'sshf', 'tcc',
#        'tcw', 'tp', 't2m_corrected'],
#       dtype='object')

# %%
print(y_train)
print(X_train)
print(y_test)
print(X_test)
# Out:
#           residue
# 0        0.496688
# 1       -0.496287
# 2        2.038780
# 3        0.579338
# 4        1.614004
# ...           ...
# 4649275  0.648722
# 4649276  0.153920
# 4649277  0.909329
# 4649278  0.331478
# 4649279  0.231375
#
# [4649280 rows x 1 columns]
#              Coast.nc  LCZcorine_UrbClim_2015_01_v1.0.nc  height.nc  \
# 0        17846.568359                               21.0   0.013173
# 1         1818.640032                               43.0   0.000000
# 2        23820.942030                                3.0   3.595983
# 3         4500.000000                               12.0   0.000000
# 4         4743.416504                               37.0   0.009319
# ...               ...                                ...        ...
# 4649275  24698.177734                               20.0   0.273453
# 4649276  33615.472656                               20.0   0.000000
# 4649277  23537.205078                                5.0   4.883322
# 4649278  22610.837891                               20.0   0.180466
# 4649279  21503.317721                               20.0   0.282049
#
#          imperv_UrbClim_2015_01_v1.0.nc  LCZ_UrbClim_2015_01_v1.0.nc  \
# 0                              0.000000                         11.0
# 1                              0.000000                         17.0
# 2                             80.113107                          4.0
# 3                              0.000000                         14.0
# 4                              1.138197                         14.0
# ...                                 ...                          ...
# 4649275                       13.208849                          6.0
# 4649276                        0.000000                         14.0
# 4649277                       75.274131                          8.0
# 4649278                        7.438143                         14.0
# 4649279                       10.746958                         14.0
#
#          population.nc   surface.nc     volume.nc  hour_sin  hour_cos  ...  \
# 0             0.239407    37.395300    131.940599  0.000000  1.000000  ...
# 1             0.000000     0.000000      0.000000  0.000000  1.000000  ...
# 2            37.861669  3413.413433  35558.741900  0.000000  1.000000  ...
# 3             0.000000     0.000000      0.000000  0.000000  1.000000  ...
# 4             0.144738    34.104503     90.541294  0.000000  1.000000  ...
# ...                ...          ...           ...       ...       ...  ...
# 4649275       6.488735   905.263331   2698.713470 -0.258819  0.965926  ...
# 4649276       0.000000     0.000000      0.000000 -0.258819  0.965926  ...
# 4649277       4.423150  5312.806173  48753.939081 -0.258819  0.965926  ...
# 4649278       3.706859   492.189881   1554.453073 -0.258819  0.965926  ...
# 4649279       0.592821  1051.177070   2808.686491 -0.258819  0.965926  ...
#
#               cape         kx           ssr            str             sp  \
# 0         0.000000  13.333500  2.328306e-10 -261182.029065  101673.279369
# 1         0.000000  14.793607  2.328306e-10 -254322.323986  101703.518292
# 2         0.000000  12.925625  2.328306e-10 -261638.229069  101641.178035
# 3         0.000000  14.924988  2.328306e-10 -253723.925018  101700.773078
# 4         0.000000  14.592812  2.328306e-10 -255032.973607  101696.280704
# ...            ...        ...           ...            ...            ...
# 4649275  80.165167  16.468732  0.000000e+00  -39914.942135  100838.283410
# 4649276  75.804965  16.249521  0.000000e+00  -38561.989466  100787.049857
# 4649277  78.752825  16.738197  0.000000e+00  -40745.837890  100838.109658
# 4649278  81.032201  16.493911  0.000000e+00  -40356.376250  100851.483535
# 4649279  73.743150  16.713719  0.000000e+00  -43026.681835  100847.624026
#
#                   sshf       tcc        tcw            tp  t2m_corrected
# 0        185846.541624  0.004802  22.257494 -1.734723e-18      20.167857
# 1        176471.302899  0.005223  22.716708 -1.734723e-18      20.217564
# 2        185178.451433  0.000000  21.983525 -1.734723e-18      20.303346
# 3        177339.575796  0.003699  22.670759 -1.734723e-18      20.185793
# 4        178209.356063  0.003766  22.606139 -1.734723e-18      20.199558
# ...                ...       ...        ...           ...            ...
# 4649275   23232.369094  1.000000  30.687755  0.000000e+00      18.102859
# 4649276   23875.428766  1.000000  30.491040  0.000000e+00      17.935552
# 4649277   22056.675060  1.000000  31.155532  2.386022e-08      18.289792
# 4649278   23175.909148  1.000000  30.716805  0.000000e+00      18.141813
# 4649279   29005.211549  1.000000  31.346064  1.185614e-07      18.428134
#
# [4649280 rows x 23 columns]
#           residue
# 0        0.201183
# 1       -0.282666
# 2       -0.470344
# 3       -0.417905
# 4       -0.511092
# ...           ...
# 6519379 -0.128181
# 6519380 -0.153050
# 6519381  0.752998
# 6519382 -0.133330
# 6519383  1.175040
#
# [6519384 rows x 1 columns]
#              Coast.nc  LCZcorine_UrbClim_2015_01_v1.0.nc  height.nc  \
# 0        70501.773438                               27.0   0.754918
# 1        70501.773438                               27.0   0.021723
# 2        70501.773438                               27.0   0.083132
# 3        70501.460168                               27.0   0.171491
# 4        70500.135050                               27.0   0.000396
# ...               ...                                ...        ...
# 6519379  45276.568443                               20.0   2.962714
# 6519380  45465.874933                               20.0   0.580635
# 6519381  45466.686275                                2.0   0.462060
# 6519382  45466.686275                                2.0   0.639786
# 6519383  45466.686275                               20.0   0.461198
#
#          imperv_UrbClim_2015_01_v1.0.nc  LCZ_UrbClim_2015_01_v1.0.nc  \
# 0                             26.158968                          8.0
# 1                              7.515803                          8.0
# 2                              3.916838                         11.0
# 3                              7.066684                         12.0
# 4                              4.039159                         12.0
# ...                                 ...                          ...
# 6519379                       34.601426                          6.0
# 6519380                        0.000000                          6.0
# 6519381                       26.967074                          6.0
# 6519382                       13.397631                          6.0
# 6519383                        5.311621                          6.0
#
#          population.nc   surface.nc     volume.nc  hour_sin  hour_cos  ...  \
# 0            10.192625  1305.673444   7422.306096  0.000000  1.000000  ...
# 1             0.580598    24.890776    173.865758  0.000000  1.000000  ...
# 2             2.534373   159.835951    758.942872  0.000000  1.000000  ...
# 3             5.507504   433.650740   1649.276210  0.000000  1.000000  ...
# 4             0.004335     0.000000      1.298288  0.000000  1.000000  ...
# ...                ...          ...           ...       ...       ...  ...
# 6519379      13.428996  2932.035976  28643.087248 -0.258819  0.965926  ...
# 6519380       8.499064  1147.435304   5733.327553 -0.258819  0.965926  ...
# 6519381       6.793756  1195.906238   4582.955048 -0.258819  0.965926  ...
# 6519382       8.868361  1652.376439   5982.448717 -0.258819  0.965926  ...
# 6519383       6.360040  1202.255483   4290.377365 -0.258819  0.965926  ...
#
#                  cape         kx  ssr            str             sp  \
# 0        2.502300e+01  21.794560  0.0 -130865.358892   99868.561039
# 1        2.510605e+01  21.795178  0.0 -130883.045176   99867.999707
# 2        2.518886e+01  21.795746  0.0 -130900.613225   99867.456139
# 3        2.527177e+01  21.796329  0.0 -130918.222842   99866.907193
# 4        2.535474e+01  21.796932  0.0 -130935.874205   99866.350981
# ...               ...        ...  ...            ...            ...
# 6519379 -9.094947e-13  15.543172  0.0 -178239.105537  101884.187474
# 6519380 -9.094947e-13  15.541132  0.0 -178232.024402  101883.899777
# 6519381 -9.094947e-13  15.539032  0.0 -178225.087555  101883.598400
# 6519382 -9.094947e-13  15.537021  0.0 -178217.932331  101883.317325
# 6519383 -9.094947e-13  15.534937  0.0 -178210.961034  101883.019550
#
#                  sshf       tcc        tcw        tp  t2m_corrected
# 0        44860.730200  1.000000  28.087934  0.000013      15.430952
# 1        44859.011015  1.000000  28.084609  0.000013      15.431769
# 2        44857.220419  1.000000  28.081336  0.000013      15.446046
# 3        44855.449798  1.000000  28.078047  0.000013      15.453177
# 4        44853.710272  1.000000  28.074737  0.000013      15.426369
# ...               ...       ...        ...       ...            ...
# 6519379  66173.706399  0.351888  26.205528  0.000000      15.404633
# 6519380  66172.052112  0.351864  26.202663  0.000000      15.423521
# 6519381  66170.495136  0.351839  26.199763  0.000000      15.424944
# 6519382  66168.792193  0.351817  26.196914  0.000000      15.416344
# 6519383  66167.210890  0.351792  26.194024  0.000000      15.420047
#
# [6519384 rows x 23 columns]

# %% [markdown]
# ### Check data quality

# %%
# 假设你的数据集是 train_set_all
# 查看每个特征的基本统计信息
print(train_set_all.describe())

# 可视化每个特征的分布
train_set_all.hist(figsize=(12, 10), bins=30)
plt.tight_layout()
plt.show()
# Out:
#                   y             x           tas      Coast.nc  \
# count  4.649280e+06  4.649280e+06  4.649280e+06  4.649280e+06
# mean   5.101925e+01  4.188511e+00  1.942078e+01  3.947044e+04
# std    3.241927e-01  3.444139e-01  5.057010e+00  3.418555e+04
# min    5.032253e+01  3.532958e+00  6.234674e+00  0.000000e+00
# 25%    5.099680e+01  3.814758e+00  1.578237e+01  1.850000e+04
# 50%    5.113689e+01  4.329845e+00  1.850826e+01  2.582570e+04
# 75%    5.123775e+01  4.466199e+00  2.249921e+01  3.785499e+04
# max    5.138953e+01  4.630889e+00  3.570394e+01  1.154264e+05
#
#        LCZcorine_UrbClim_2015_01_v1.0.nc     height.nc  \
# count                       4.649280e+06  4.649280e+06
# mean                        1.309488e+01  8.298270e-01
# std                         1.052706e+01  1.573080e+00
# min                         1.000000e+00  0.000000e+00
# 25%                         2.000000e+00  0.000000e+00
# 50%                         1.200000e+01  1.027838e-01
# 75%                         2.000000e+01  8.627847e-01
# max                         4.300000e+01  1.579885e+01
#
#        imperv_UrbClim_2015_01_v1.0.nc  LCZ_UrbClim_2015_01_v1.0.nc  \
# count                    4.649280e+06                 4.649280e+06
# mean                     1.618079e+01                 1.038819e+01
# std                      2.553157e+01                 3.558433e+00
# min                      0.000000e+00                 1.000000e+00
# 25%                      0.000000e+00                 6.000000e+00
# 50%                      1.833506e+00                 1.100000e+01
# 75%                      2.302888e+01                 1.400000e+01
# max                      1.000000e+02                 1.700000e+01
#
#        population.nc    surface.nc  ...          cape            kx  \
# count   4.649280e+06  4.649280e+06  ...  4.649280e+06  4.649280e+06
# mean    9.335767e+00  1.029065e+03  ...  1.533058e+02  1.640331e+01
# std     1.762087e+01  1.421517e+03  ...  3.738854e+02  1.222933e+01
# min     0.000000e+00  0.000000e+00  ...  0.000000e+00 -2.070600e+01
# 25%     0.000000e+00  0.000000e+00  ...  0.000000e+00  8.271513e+00
# 50%     1.426915e+00  2.997107e+02  ...  6.504141e+00  1.812755e+01
# 75%     1.050030e+01  1.668404e+03  ...  5.222269e+01  2.578833e+01
# max     1.560948e+02  9.566714e+03  ...  3.019253e+03  4.091442e+01
#
#                 ssr           str            sp          sshf           tcc  \
# count  4.649280e+06  4.649280e+06  4.649280e+06  4.649280e+06  4.649280e+06
# mean   7.300935e+05 -2.217464e+05  1.012407e+05 -9.647091e+04  5.608773e-01
# std    7.927042e+05  8.945282e+04  8.047582e+02  2.149134e+05  3.571543e-01
# min    0.000000e+00 -4.725378e+05  9.866564e+04 -9.523776e+05  0.000000e+00
# 25%    2.328306e-10 -2.793627e+05  1.008055e+05 -2.347049e+05  2.442779e-01
# 50%    4.248460e+05 -2.195089e+05  1.014979e+05 -4.855506e+02  5.841481e-01
# 75%    1.392400e+06 -1.594543e+05  1.018386e+05  5.839896e+04  9.337060e-01
# max    2.658832e+06 -1.589082e+04  1.024719e+05  2.290121e+05  1.000000e+00
#
#                 tcw            tp  t2m_corrected
# count  4.649280e+06  4.649280e+06   4.649280e+06
# mean   2.529997e+01  7.056361e-05   1.912681e+01
# std    7.037305e+00  2.930592e-04   4.944439e+00
# min    1.206493e+01 -1.734723e-18   6.075831e+00
# 25%    1.949024e+01 -1.734723e-18   1.577299e+01
# 50%    2.428253e+01  0.000000e+00   1.810515e+01
# 75%    3.082224e+01  2.081798e-05   2.234942e+01
# max    4.455322e+01  5.927446e-03   3.472964e+01
#
# [8 rows x 27 columns]

# %%
print(test_set.describe())

# 可视化每个特征的分布
test_set.hist(figsize=(12, 10), bins=30)
plt.tight_layout()
plt.show()
# Out:
#                       time             y             x           tas  \
# count              6519384  6.519384e+06  6.519384e+06  6.519384e+06
# mean   2017-07-02 11:30:00  5.084335e+01  4.372353e+00  1.645012e+01
# min    2017-07-01 00:00:00  5.070001e+01  4.143460e+00  8.665125e+00
# 25%    2017-07-01 17:45:00  5.077597e+01  4.265861e+00  1.473641e+01
# 50%    2017-07-02 11:30:00  5.084336e+01  4.372366e+00  1.592233e+01
# 75%    2017-07-03 05:15:00  5.091073e+01  4.478880e+00  1.786710e+01
# max    2017-07-03 23:00:00  5.098723e+01  4.599575e+00  2.425097e+01
# std                    NaN  7.802335e-02  1.233621e-01  2.791726e+00
#
#            Coast.nc  LCZcorine_UrbClim_2015_01_v1.0.nc     height.nc  \
# count  6.519384e+06                       6.519384e+06  6.519384e+06
# mean   5.696296e+04                       1.001934e+01  1.002972e+00
# min    4.031199e+04                       1.000000e+00  0.000000e+00
# 25%    4.954039e+04                       2.000000e+00  3.886324e-04
# 50%    5.700000e+04                       1.000000e+01  1.556705e-01
# 75%    6.434692e+04                       2.000000e+01  1.128480e+00
# max    7.418121e+04                       4.100000e+01  2.299535e+01
# std    8.652394e+03                       8.290704e+00  1.812918e+00
#
#        imperv_UrbClim_2015_01_v1.0.nc  LCZ_UrbClim_2015_01_v1.0.nc  \
# count                    6.519384e+06                 6.519384e+06
# mean                     1.648304e+01                 9.452428e+00
# min                      0.000000e+00                 1.000000e+00
# 25%                      0.000000e+00                 6.000000e+00
# 50%                      2.941986e+00                 9.000000e+00
# 75%                      2.411371e+01                 1.200000e+01
# max                      1.000000e+02                 1.700000e+01
# std                      2.462228e+01                 3.559847e+00
#
#        population.nc  ...          cape            kx           ssr  \
# count   6.519384e+06  ...  6.519384e+06  6.519384e+06  6.519384e+06
# mean    1.929276e+01  ...  1.631597e+01  1.460073e+01  4.189088e+05
# min     0.000000e+00  ... -9.094947e-13 -8.896406e+00  0.000000e+00
# 25%     3.710244e-03  ... -9.094947e-13  4.043045e+00  0.000000e+00
# 50%     2.830911e+00  ...  7.345162e+00  1.835272e+01  1.159734e+05
# 75%     1.748164e+01  ...  2.883376e+01  2.392582e+01  5.496229e+05
# max     4.775592e+02  ...  9.329078e+01  2.756112e+01  2.149768e+06
# std     4.227147e+01  ...  2.007024e+01  1.103268e+01  5.926751e+05
#
#                 str            sp          sshf           tcc           tcw  \
# count  6.519384e+06  6.519384e+06  6.519384e+06  6.519384e+06  6.519384e+06
# mean  -1.623897e+05  1.011694e+05 -3.785076e+04  6.019156e-01  2.586138e+01
# min   -3.626836e+05  9.961032e+04 -5.647396e+05  0.000000e+00  1.291405e+01
# 25%   -2.576386e+05  1.008637e+05 -5.552435e+04  1.962285e-01  2.117832e+01
# 50%   -1.315901e+05  1.012963e+05  3.060822e+04  6.873559e-01  2.578239e+01
# 75%   -6.330461e+04  1.015743e+05  5.710983e+04  1.000000e+00  3.150848e+01
# max   -1.451135e+04  1.021410e+05  1.172706e+05  1.000000e+00  3.672186e+01
# std    1.040859e+05  5.446208e+02  1.582043e+05  3.828726e-01  6.657642e+00
#
#                  tp  t2m_corrected
# count  6.519384e+06   6.519384e+06
# mean   1.759216e-04   1.570253e+01
# min    0.000000e+00   7.344600e+00
# 25%    0.000000e+00   1.406285e+01
# 50%    0.000000e+00   1.537543e+01
# 75%    5.539263e-05   1.769636e+01
# max    2.445147e-03   2.290216e+01
# std    4.512045e-04   3.165624e+00
#
# [8 rows x 28 columns]

# %%
def plot_tem_over_time(df,city):
    plt.figure(figsize=(12, 6))
    plt.plot(df['time'], df['tas'], label='TAS (Temperature)', color='blue', linestyle='-', linewidth=1)
    plt.plot(df['time'], df['t2m_corrected'], label='T2M Corrected', color='orange', linestyle='--', linewidth=1)
    plt.legend()
    plt.title(f'Temperature Trends Over Time {city}', fontsize=16)
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Temperature (°C)', fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
plot_tem_over_time(test_set,'Brussels')

# %% [markdown]
# ### Util code

# %%
def plot_y(df, model_name, feature_name):
  plt.figure(figsize=(10, 8))
  plt.scatter(df['x'], df['y'], c=df[feature_name], cmap='viridis', s=1, vmin = 13, vmax = 19)  # 使用 'viridis' 色彩映射
  # plt.scatter(df['x'], df['y'], c=df[feature_name], cmap='viridis', s=1)
  plt.colorbar(label= feature_name)
  plt.xlabel('Longitude (x)')
  plt.ylabel('Latitude (y)')
  plt.title(f'Geographical Distribution of Temperature - {model_name}')
  plt.show()

# %%
# compute the errors
# compute MAE (Mean Absolute Error)
def calculate_errors(y_test, y_pred):
    mae = mean_absolute_error(y_test, y_pred)
    print(f"Mean Absolute Error (MAE): {mae}")
    
    # compute MSE (Mean Squared Error)
    mse = mean_squared_error(y_test, y_pred)
    print(f"Mean Squared Error (MSE): {mse}")
    
    # compute RMSE (Root Mean Squared Error)
    rmse = np.sqrt(mse)
    print(f"Root Mean Squared Error (RMSE): {rmse}")

    return mae, mse, rmse

# %% [markdown]
# ### Baseline computation

# %%
maes_general = {}
maes_day = {}
maes_night = {}

mses_general = {}
mses_day = {}
mses_night = {}

rmses_general = {}
rmses_day = {}
rmses_night = {}
errors = {"general_error": [maes_general, mses_general, rmses_general], "day_error":[ maes_day, mses_day, rmses_day], "night_error":[maes_night mses_night, rmses_night]}

# %%
# first_timestamp_true = urbclim_true_value[(urbclim_true_value['time']=="2016-07-01 00:00:00") | (urbclim_true_value['time']=="2016-07-01")]
first_timestamp_true = test_set[(test_set['time']=="2017-07-01 00:00:00")][['tas','x','y']]
print(first_timestamp_true)
tas_min = first_timestamp_true['tas'].min()
tas_max = first_timestamp_true['tas'].max()
print("tas min: " ,tas_min)
print("tas max: " ,tas_max)
plot_y(first_timestamp_true, 'True data', 'tas')
# Out:
#              tas         x          y
# 0      15.632135  4.207803  50.700043
# 1      15.149103  4.209215  50.700110
# 2      14.975702  4.210626  50.700184
# 3      15.035272  4.212038  50.700256
# 4      14.915277  4.213450  50.700325
# ...          ...       ...        ...
# 90542  15.303064  4.547782  50.986958
# 90543  15.286371  4.549203  50.987026
# 90544  15.476862  4.550624  50.987090
# 90545  15.270410  4.552045  50.987160
# 90546  15.791254  4.553465  50.987225
#
# [90547 rows x 3 columns]
# tas min:  14.061822509765648
# tas max:  17.839501953125023

# %%
# calculate the error matric for corrected era5 with urbclim for test set
urbclim_true = test_set['tas']
era5_true = test_set['t2m_corrected']
test_set['time'] = pd.to_datetime(test_set['time'], format='mixed')
urbclim_true_day = test_set[(test_set['time'].dt.hour >= 6) & (test_set['time'].dt.hour < 18)][['tas']]
urbclim_true_night =  test_set[(test_set['time'].dt.hour < 6) | (test_set['time'].dt.hour >= 18)][['tas']]
era5_true_day = test_set[(test_set['time'].dt.hour >= 6) & (test_set['time'].dt.hour < 18)][['t2m_corrected']]
era5_true_night = test_set[(test_set['time'].dt.hour < 6) | (test_set['time'].dt.hour >= 18)][['t2m_corrected']]

# %%
model_name = "baseline"
maes_general[model_name], mses_general[model_name], rmses_general[model_name] = calculate_errors(urbclim_true, era5_true)
print("Errors during day:")
maes_day[model_name], mses_day[model_name], rmses_day[model_name] = calculate_errors(urbclim_true_day['tas'], era5_true_day['t2m_corrected'])
print("Errors during night:")
maes_night[model_name], mses_night[model_name],  rmses_night[model_name] = calculate_errors(urbclim_true_night['tas'], era5_true_night['t2m_corrected'])
# Out:
# Mean Absolute Error (MAE): 0.9105989203665271
# Mean Squared Error (MSE): 1.802738099139393
# Root Mean Squared Error (RMSE): 1.342660828034911
# Errors during day:
# Mean Absolute Error (MAE): 0.5083054612297256
# Mean Squared Error (MSE): 0.39624445609045195
# Root Mean Squared Error (RMSE): 0.6294795120497981
# Errors during night:
# Mean Absolute Error (MAE): 1.3128923795033283
# Mean Squared Error (MSE): 3.2092317421883325
# Root Mean Squared Error (RMSE): 1.7914328740391956

# %% [markdown]
# ### Scale data

# %%
from sklearn.preprocessing import MinMaxScaler
# Initialize the normalizer
scaler = MinMaxScaler(feature_range=(0, 1))

# Normalize the training set
X_train_normalized = scaler.fit_transform(X_train)

# Normalize the test set using the parameters of the training set
X_test_normalized = scaler.transform(X_test)

# %%
y_test[['y','x','time']] = test_set[['y','x','time']]
y_test_day = y_test[(y_test['time'].dt.hour >= 6) & (y_test['time'].dt.hour < 18)]
y_test_night = y_test[(y_test['time'].dt.hour < 6) | (y_test['time'].dt.hour >= 18)]

# %% [markdown]
# ### Linear regression model

# %%
linear_model = LinearRegression()
linear_model.fit(X_train_normalized, y_train)


# Predict y
y_pred_lr = linear_model.predict(X_test_normalized)
y_pred_lr = pd.DataFrame(y_pred_lr, columns=['residue'])
print(y_pred_lr)
# Out:
#           residue
# 0        1.106039
# 1        1.023254
# 2        0.805922
# 3        0.751163
# 4        0.750246
# ...           ...
# 6519379  0.650779
# 6519380  0.422922
# 6519381  0.854477
# 6519382  0.763527
# 6519383  0.444722
#
# [6519384 rows x 1 columns]

# %%
y_pred_lr[['y','x','time']] = test_set[['y','x','time']]
y_pred_lr_day = y_pred_lr[(y_pred_lr['time'].dt.hour >= 6) & (y_pred_lr['time'].dt.hour < 18)]
y_pred_lr_night = y_pred_lr[(y_pred_lr['time'].dt.hour < 6) | (y_pred_lr['time'].dt.hour >= 18)]

print(y_pred_lr_day)
print(y_pred_lr_night)
print(y_test_day)
print(y_test_night)
# Out:
#           residue          y         x                time
# 543282   0.090005  50.700043  4.207803 2017-07-01 06:00:00
# 543283   0.006937  50.700110  4.209215 2017-07-01 06:00:00
# 543284  -0.210674  50.700184  4.210626 2017-07-01 06:00:00
# 543285  -0.265714  50.700256  4.212038 2017-07-01 06:00:00
# 543286  -0.266913  50.700325  4.213450 2017-07-01 06:00:00
# ...           ...        ...       ...                 ...
# 5976097 -0.349751  50.986958  4.547782 2017-07-03 17:00:00
# 5976098 -0.578263  50.987026  4.549203 2017-07-03 17:00:00
# 5976099 -0.147363  50.987090  4.550624 2017-07-03 17:00:00
# 5976100 -0.238967  50.987160  4.552045 2017-07-03 17:00:00
# 5976101 -0.558427  50.987225  4.553465 2017-07-03 17:00:00
#
# [3259692 rows x 4 columns]
#           residue          y         x                time
# 0        1.106039  50.700043  4.207803 2017-07-01 00:00:00
# 1        1.023254  50.700110  4.209215 2017-07-01 00:00:00
# 2        0.805922  50.700184  4.210626 2017-07-01 00:00:00
# 3        0.751163  50.700256  4.212038 2017-07-01 00:00:00
# 4        0.750246  50.700325  4.213450 2017-07-01 00:00:00
# ...           ...        ...       ...                 ...
# 6519379  0.650779  50.986958  4.547782 2017-07-03 23:00:00
# 6519380  0.422922  50.987026  4.549203 2017-07-03 23:00:00
# 6519381  0.854477  50.987090  4.550624 2017-07-03 23:00:00
# 6519382  0.763527  50.987160  4.552045 2017-07-03 23:00:00
# 6519383  0.444722  50.987225  4.553465 2017-07-03 23:00:00
#
# [3259692 rows x 4 columns]
#           residue          y         x                time
# 543282   0.598045  50.700043  4.207803 2017-07-01 06:00:00
# 543283   0.501219  50.700110  4.209215 2017-07-01 06:00:00
# 543284   0.415629  50.700184  4.210626 2017-07-01 06:00:00
# 543285   0.384270  50.700256  4.212038 2017-07-01 06:00:00
# 543286   0.371193  50.700325  4.213450 2017-07-01 06:00:00
# ...           ...        ...       ...                 ...
# 5976097  0.190022  50.986958  4.547782 2017-07-03 17:00:00
# 5976098  0.208353  50.987026  4.549203 2017-07-03 17:00:00
# 5976099  0.645874  50.987090  4.550624 2017-07-03 17:00:00
# 5976100  0.214036  50.987160  4.552045 2017-07-03 17:00:00
# 5976101  0.342028  50.987225  4.553465 2017-07-03 17:00:00
#
# [3259692 rows x 4 columns]
#           residue          y         x                time
# 0        0.201183  50.700043  4.207803 2017-07-01 00:00:00
# 1       -0.282666  50.700110  4.209215 2017-07-01 00:00:00
# 2       -0.470344  50.700184  4.210626 2017-07-01 00:00:00
# 3       -0.417905  50.700256  4.212038 2017-07-01 00:00:00
# 4       -0.511092  50.700325  4.213450 2017-07-01 00:00:00
# ...           ...        ...       ...                 ...
# 6519379 -0.128181  50.986958  4.547782 2017-07-03 23:00:00
# 6519380 -0.153050  50.987026  4.549203 2017-07-03 23:00:00
# 6519381  0.752998  50.987090  4.550624 2017-07-03 23:00:00
# 6519382 -0.133330  50.987160  4.552045 2017-07-03 23:00:00
# 6519383  1.175040  50.987225  4.553465 2017-07-03 23:00:00
#
# [3259692 rows x 4 columns]

# %%
print("Errors:")
model_name = "LR"
maes_general[model_name], mses_general[model_name], rmses_general[model_name] = calculate_errors(y_test['residue'], y_pred_lr['residue'])
print("Errors during day:")
maes_day[model_name], mses_day[model_name], rmses_day[model_name] = calculate_errors(y_test_day['residue'], y_pred_lr_day['residue'])
print("Errors during night:")
maes_night[model_name], mses_night[model_name],  rmses_night[model_name] = calculate_errors(y_test_night['residue'], y_pred_lr_night['residue'])
# Out:
# Errors:
# Mean Absolute Error (MAE): 0.8084609234941019
# Mean Squared Error (MSE): 1.1779617899544808
# Root Mean Squared Error (RMSE): 1.0853394814317228
# Errors during day:
# Mean Absolute Error (MAE): 0.658523180234547
# Mean Squared Error (MSE): 0.6421160041410326
# Root Mean Squared Error (RMSE): 0.8013214112583243
# Errors during night:
# Mean Absolute Error (MAE): 0.9583986667536579
# Mean Squared Error (MSE): 1.7138075757679287
# Root Mean Squared Error (RMSE): 1.3091247365197591

# %%
# sum up y_pred and corrected ERA5 to get the urbclim prediction
urbclim_pred_lr = pd.DataFrame()

urbclim_pred_lr['tas'] = y_pred_lr['residue'] + test_set['t2m_corrected']
urbclim_pred_lr[['y','x','time']] = test_set[['y','x','time']]

print(urbclim_pred_lr)
# Out:
#                tas          y         x                time
# 0        16.536991  50.700043  4.207803 2017-07-01 00:00:00
# 1        16.455023  50.700110  4.209215 2017-07-01 00:00:00
# 2        16.251968  50.700184  4.210626 2017-07-01 00:00:00
# 3        16.204340  50.700256  4.212038 2017-07-01 00:00:00
# 4        16.176615  50.700325  4.213450 2017-07-01 00:00:00
# ...            ...        ...       ...                 ...
# 6519379  16.055412  50.986958  4.547782 2017-07-03 23:00:00
# 6519380  15.846443  50.987026  4.549203 2017-07-03 23:00:00
# 6519381  16.279421  50.987090  4.550624 2017-07-03 23:00:00
# 6519382  16.179871  50.987160  4.552045 2017-07-03 23:00:00
# 6519383  15.864768  50.987225  4.553465 2017-07-03 23:00:00
#
# [6519384 rows x 4 columns]

# %%
# extract the first timestamp y_pred and plot it
# first_stamp_data = urbclim_pred[(urbclim_pred['time']=="2015-07-01 00:00:00") | (urbclim_pred['time']=="2015-07-01")]
first_stamp_data_lr = urbclim_pred_lr[(urbclim_pred_lr['time']=="2017-07-01 00:00:00")]
print(first_stamp_data_lr)
tas_min_lr = first_stamp_data_lr['tas'].min()
tas_max_lr = first_stamp_data_lr['tas'].max()
print("tas min: " ,tas_min_lr)
print("tas max: " ,tas_max_lr)
plot_y(first_stamp_data_lr, 'Linear regression - urbclim tas', 'tas')
# Out:
#              tas          y         x       time
# 0      16.536991  50.700043  4.207803 2017-07-01
# 1      16.455023  50.700110  4.209215 2017-07-01
# 2      16.251968  50.700184  4.210626 2017-07-01
# 3      16.204340  50.700256  4.212038 2017-07-01
# 4      16.176615  50.700325  4.213450 2017-07-01
# ...          ...        ...       ...        ...
# 90542  16.985128  50.986958  4.547782 2017-07-01
# 90543  16.775376  50.987026  4.549203 2017-07-01
# 90544  17.207582  50.987090  4.550624 2017-07-01
# 90545  17.107245  50.987160  4.552045 2017-07-01
# 90546  16.791368  50.987225  4.553465 2017-07-01
#
# [90547 rows x 4 columns]
# tas min:  15.12020512011538
# tas max:  18.676887562863048

# %% [markdown]
# ### NN model

# %%
# Hyperparameter definition
input_size = X_train.shape[1]  
hidden_sizes = [100, 50, 10]  # hidden layer size
output_size = 1  
learning_rate = 0.001
epochs = 10
# early_stopping_patience = 2

# %%
# Define the NN model
class NNmodel(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size):
        super(NNmodel, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, hidden_sizes[0]),
            nn.ReLU(),
            nn.Linear(hidden_sizes[0], hidden_sizes[1]),
            nn.ReLU(),
            nn.Linear(hidden_sizes[1], hidden_sizes[2]),
            nn.ReLU(),
            nn.Linear(hidden_sizes[2], output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
# Create a model instance
model = NNmodel(input_size, hidden_sizes, output_size)
criterion = nn.MSELoss()  # Loss function
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Data preparation
train_dataset = TensorDataset(torch.tensor(X_train_normalized, dtype=torch.float32), 
                               torch.tensor(y_train['residue'], dtype=torch.float32))
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = TensorDataset(torch.tensor(X_test_normalized, dtype=torch.float32), 
                             torch.tensor(y_test['residue'], dtype=torch.float32))
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Model training
best_val_loss = float('inf')
patience_counter = 0
train_losses = []
val_losses = []

for epoch in range(epochs):
    model.train()
    train_loss = 0.0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs.squeeze(), y_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    
    # Model validation
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            outputs = model(X_batch)
            loss = criterion(outputs.squeeze(), y_batch)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    
    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
    
    # Early Stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        # patience_counter = 0
        best_model_state = model.state_dict()  # Save the Optimal result
    # else:
    #     patience_counter += 1
    #     if patience_counter >= early_stopping_patience:
    #         print("Early stopping triggered!")
    #         break
# Out:
# Epoch 1/10, Train Loss: 0.3857, Val Loss: 0.8749
# Epoch 2/10, Train Loss: 0.2880, Val Loss: 0.8615
# Epoch 3/10, Train Loss: 0.2632, Val Loss: 1.0574
# Epoch 4/10, Train Loss: 0.2497, Val Loss: 1.0631
# Epoch 5/10, Train Loss: 0.2408, Val Loss: 1.1333
# Epoch 6/10, Train Loss: 0.2345, Val Loss: 1.0275
# Epoch 7/10, Train Loss: 0.2300, Val Loss: 1.0852
# Epoch 8/10, Train Loss: 0.2262, Val Loss: 1.0948
# Epoch 9/10, Train Loss: 0.2235, Val Loss: 1.0554
# Epoch 10/10, Train Loss: 0.2213, Val Loss: 1.1846

# %%
def plot_losses(train_loss, val_loss):

    epochs = range(1, len(train_loss) + 1)

    plt.plot(epochs, train_loss, '--', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %%
plot_losses(train_loss=train_losses, val_loss=val_losses)

# %%
# Load the optimal model
model.load_state_dict(best_model_state)

# Test set prediction
X_test_tensor = torch.tensor(X_test_normalized, dtype=torch.float32)
y_pred = model(X_test_tensor).detach().numpy()

# Transform into DataFrame
y_pred_nn = pd.DataFrame(y_pred, columns=['residue'])
print(y_pred_nn)
# Out:
#           residue
# 0        1.400224
# 1        1.147698
# 2        1.094942
# 3        1.125292
# 4        1.055565
# ...           ...
# 6519379  0.175238
# 6519380 -0.775215
# 6519381  0.315550
# 6519382  0.117337
# 6519383 -0.800727
#
# [6519384 rows x 1 columns]

# %%
y_pred_nn[['y','x','time']] = test_set[['y','x','time']]

y_pred_nn_day = y_pred_nn[(y_pred_nn['time'].dt.hour >= 6) & (y_pred_nn['time'].dt.hour < 18)]
y_pred_nn_night = y_pred_nn[(y_pred_nn['time'].dt.hour < 6) | (y_pred_nn['time'].dt.hour >= 18)]

print(y_pred_nn_day)
print(y_pred_nn_night)
# Out:
#           residue          y         x                time
# 543282   1.446966  50.700043  4.207803 2017-07-01 06:00:00
# 543283   1.308223  50.700110  4.209215 2017-07-01 06:00:00
# 543284   1.271282  50.700184  4.210626 2017-07-01 06:00:00
# 543285   1.296026  50.700256  4.212038 2017-07-01 06:00:00
# 543286   1.242889  50.700325  4.213450 2017-07-01 06:00:00
# ...           ...        ...       ...                 ...
# 5976097 -0.342396  50.986958  4.547782 2017-07-03 17:00:00
# 5976098 -0.495874  50.987026  4.549203 2017-07-03 17:00:00
# 5976099 -0.374820  50.987090  4.550624 2017-07-03 17:00:00
# 5976100 -0.365573  50.987160  4.552045 2017-07-03 17:00:00
# 5976101 -0.481121  50.987225  4.553465 2017-07-03 17:00:00
#
# [3259692 rows x 4 columns]
#           residue          y         x                time
# 0        1.400224  50.700043  4.207803 2017-07-01 00:00:00
# 1        1.147698  50.700110  4.209215 2017-07-01 00:00:00
# 2        1.094942  50.700184  4.210626 2017-07-01 00:00:00
# 3        1.125292  50.700256  4.212038 2017-07-01 00:00:00
# 4        1.055565  50.700325  4.213450 2017-07-01 00:00:00
# ...           ...        ...       ...                 ...
# 6519379  0.175238  50.986958  4.547782 2017-07-03 23:00:00
# 6519380 -0.775215  50.987026  4.549203 2017-07-03 23:00:00
# 6519381  0.315550  50.987090  4.550624 2017-07-03 23:00:00
# 6519382  0.117337  50.987160  4.552045 2017-07-03 23:00:00
# 6519383 -0.800727  50.987225  4.553465 2017-07-03 23:00:00
#
# [3259692 rows x 4 columns]

# %%
model_name = "NN"
maes_general[model_name], mses_general[model_name], rmses_general[model_name] = calculate_errors(y_test['residue'], y_pred_nn['residue'])
print("Errors during day:")
maes_day[model_name], mses_day[model_name], rmses_day[model_name] = calculate_errors(y_test_day['residue'], y_pred_nn_day['residue'])
print("Errors during night:")
maes_night[model_name], mses_night[model_name], rmses_night[model_name] = calculate_errors(y_test_night['residue'], y_pred_nn_night['residue'])
# Out:
# Mean Absolute Error (MAE): 0.8267488003740332
# Mean Squared Error (MSE): 1.184618010347281
# Root Mean Squared Error (RMSE): 1.0884015850536424
# Errors during day:
# Mean Absolute Error (MAE): 0.7681844718150495
# Mean Squared Error (MSE): 0.9713282883611217
# Root Mean Squared Error (RMSE): 0.9855598857305028
# Errors during night:
# Mean Absolute Error (MAE): 0.8853131289330164
# Mean Squared Error (MSE): 1.3979077323334395
# Root Mean Squared Error (RMSE): 1.1823314815792734

# %%
# plot NN model predicted tas
urbclim_pred_nn = pd.DataFrame()

urbclim_pred_nn['tas'] = y_pred_nn['residue'] + test_set['t2m_corrected']
urbclim_pred_nn[['y','x','time']] = test_set[['y','x','time']]

print(urbclim_pred_nn)

first_stamp_data_nn = urbclim_pred_nn[(urbclim_pred_nn['time']=="2017-07-01 00:00:00")]
print(first_stamp_data_nn)
tas_min_nn = first_stamp_data_nn['tas'].min()
tas_max_nn = first_stamp_data_nn['tas'].max()
print("tas min: " ,tas_min_nn)
print("tas max: " ,tas_max_nn)
plot_y(first_stamp_data_nn, 'NN model - urbclim tas', 'tas')
# Out:
#                tas          y         x                time
# 0        16.831177  50.700043  4.207803 2017-07-01 00:00:00
# 1        16.579467  50.700110  4.209215 2017-07-01 00:00:00
# 2        16.540988  50.700184  4.210626 2017-07-01 00:00:00
# 3        16.578470  50.700256  4.212038 2017-07-01 00:00:00
# 4        16.481934  50.700325  4.213450 2017-07-01 00:00:00
# ...            ...        ...       ...                 ...
# 6519379  15.579871  50.986958  4.547782 2017-07-03 23:00:00
# 6519380  14.648306  50.987026  4.549203 2017-07-03 23:00:00
# 6519381  15.740494  50.987090  4.550624 2017-07-03 23:00:00
# 6519382  15.533681  50.987160  4.552045 2017-07-03 23:00:00
# 6519383  14.619320  50.987225  4.553465 2017-07-03 23:00:00
#
# [6519384 rows x 4 columns]
#              tas          y         x       time
# 0      16.831177  50.700043  4.207803 2017-07-01
# 1      16.579467  50.700110  4.209215 2017-07-01
# 2      16.540988  50.700184  4.210626 2017-07-01
# 3      16.578470  50.700256  4.212038 2017-07-01
# 4      16.481934  50.700325  4.213450 2017-07-01
# ...          ...        ...       ...        ...
# 90542  16.919193  50.986958  4.547782 2017-07-01
# 90543  16.534279  50.987026  4.549203 2017-07-01
# 90544  16.883966  50.987090  4.550624 2017-07-01
# 90545  16.856313  50.987160  4.552045 2017-07-01
# 90546  16.623709  50.987225  4.553465 2017-07-01
#
# [90547 rows x 4 columns]
# tas min:  1.2111159121309054
# tas max:  20.05564606566084

# %% [markdown]
# ### MLP model

# %%
#use ANN model to predict the temp
from sklearn.neural_network import MLPRegressor


ann_model = MLPRegressor(hidden_layer_sizes=(100, 50, 10),
                                activation='relu',
                                solver='adam',
                                max_iter=100,
                                random_state=45,
                                early_stopping=True,
                                validation_fraction=0.1,
                                n_iter_no_change=20,
                                verbose=True,
                                alpha=0.03)

# %%
# y_train = y_train.ravel()
ann_model.fit(X_train_normalized, y_train)

# Plot training loss
plt.plot(ann_model.loss_curve_)
plt.title("Training Loss Curve")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.show()

y_pred_mlp = ann_model.predict(X_test_normalized)
y_pred_mlp = pd.DataFrame(y_pred_mlp, columns=['residue'])
print(y_pred_mlp)
# Out:
# /Users/wangy/Documents/MACS/Thesis/thesis_code/thesis_featurevisual/venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1631: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 0.23750940
# Validation score: 0.796973
# Iteration 2, loss = 0.18176985
# Validation score: 0.823344
# Iteration 3, loss = 0.16904606
# Validation score: 0.838974
# Iteration 4, loss = 0.16279524
# Validation score: 0.836841
# Iteration 5, loss = 0.15819767
# Validation score: 0.841223
# Iteration 6, loss = 0.15429232
# Validation score: 0.851121
# Iteration 7, loss = 0.15155882
# Validation score: 0.849124
# Iteration 8, loss = 0.14978729
# Validation score: 0.851691
# Iteration 9, loss = 0.14850430
# Validation score: 0.852910
# Iteration 10, loss = 0.14762115
# Validation score: 0.855241
# Iteration 11, loss = 0.14682998
# Validation score: 0.861969
# Iteration 12, loss = 0.14623210
# Validation score: 0.858008
# Iteration 13, loss = 0.14570694
# Validation score: 0.860552
# Iteration 14, loss = 0.14535716
# Validation score: 0.864658
# Iteration 15, loss = 0.14482353
# Validation score: 0.863523
# Iteration 16, loss = 0.14437763
# Validation score: 0.862907
# Iteration 17, loss = 0.14402837
# Validation score: 0.860516
# Iteration 18, loss = 0.14385735
# Validation score: 0.845053
# Iteration 19, loss = 0.14355483
# Validation score: 0.858064
# Iteration 20, loss = 0.14335376
# Validation score: 0.867086
# Iteration 21, loss = 0.14321514
# Validation score: 0.864493
# Iteration 22, loss = 0.14288646
# Validation score: 0.856771
# Iteration 23, loss = 0.14259538
# Validation score: 0.856712
# Iteration 24, loss = 0.14239490
# Validation score: 0.866042
# Iteration 25, loss = 0.14215666
# Validation score: 0.864356
# Iteration 26, loss = 0.14211128
# Validation score: 0.859440
# Iteration 27, loss = 0.14207698
# Validation score: 0.865032
# Iteration 28, loss = 0.14181460
# Validation score: 0.865762
# Iteration 29, loss = 0.14159974
# Validation score: 0.867880
# Iteration 30, loss = 0.14155398
# Validation score: 0.866140
# Iteration 31, loss = 0.14145588
# Validation score: 0.864894
# Iteration 32, loss = 0.14135805
# Validation score: 0.867549
# Iteration 33, loss = 0.14114029
# Validation score: 0.866001
# Iteration 34, loss = 0.14116852
# Validation score: 0.868787
# Iteration 35, loss = 0.14096411
# Validation score: 0.864775
# Iteration 36, loss = 0.14082338
# Validation score: 0.866141
# Iteration 37, loss = 0.14080592
# Validation score: 0.853722
# Iteration 38, loss = 0.14078409
# Validation score: 0.861343
# Iteration 39, loss = 0.14079491
# Validation score: 0.867736
# Iteration 40, loss = 0.14063487
# Validation score: 0.867673
# Iteration 41, loss = 0.14061703
# Validation score: 0.859512
# Iteration 42, loss = 0.14055464
# Validation score: 0.858766
# Iteration 43, loss = 0.14038145
# Validation score: 0.868086
# Iteration 44, loss = 0.14030035
# Validation score: 0.869958
# Iteration 45, loss = 0.14029670
# Validation score: 0.863490
# Iteration 46, loss = 0.14031217
# Validation score: 0.868954
# Iteration 47, loss = 0.14015105
# Validation score: 0.863280
# Iteration 48, loss = 0.14016111
# Validation score: 0.866395
# Iteration 49, loss = 0.14004068
# Validation score: 0.868235
# Iteration 50, loss = 0.14005515
# Validation score: 0.867607
# Iteration 51, loss = 0.14002072
# Validation score: 0.866408
# Iteration 52, loss = 0.13995190
# Validation score: 0.869561
# Iteration 53, loss = 0.13987491
# Validation score: 0.864726
# Iteration 54, loss = 0.13976663
# Validation score: 0.860848
# Iteration 55, loss = 0.13969818
# Validation score: 0.860129
# Iteration 56, loss = 0.13964430
# Validation score: 0.869097
# Iteration 57, loss = 0.13973168
# Validation score: 0.866669
# Iteration 58, loss = 0.13963376
# Validation score: 0.866198
# Iteration 59, loss = 0.13964107
# Validation score: 0.867363
# Iteration 60, loss = 0.13943676
# Validation score: 0.865170
# Iteration 61, loss = 0.13956589
# Validation score: 0.868996
# Iteration 62, loss = 0.13949937
# Validation score: 0.868127
# Iteration 63, loss = 0.13949388
# Validation score: 0.859174
# Iteration 64, loss = 0.13944042
# Validation score: 0.868646
# Iteration 65, loss = 0.13957411
# Validation score: 0.872079
# Iteration 66, loss = 0.13947573
# Validation score: 0.858589
# Iteration 67, loss = 0.13941025
# Validation score: 0.864789
# Iteration 68, loss = 0.13950112
# Validation score: 0.863943
# Iteration 69, loss = 0.13943298
# Validation score: 0.869166
# Iteration 70, loss = 0.13933448
# Validation score: 0.863479
# Iteration 71, loss = 0.13937695
# Validation score: 0.867950
# Iteration 72, loss = 0.13940426
# Validation score: 0.858774
# Iteration 73, loss = 0.13942525
# Validation score: 0.866449
# Iteration 74, loss = 0.13924625
# Validation score: 0.867407
# Iteration 75, loss = 0.13931450
# Validation score: 0.866661
# Iteration 76, loss = 0.13925286
# Validation score: 0.862468
# Iteration 77, loss = 0.13938185
# Validation score: 0.867430
# Iteration 78, loss = 0.13917221
# Validation score: 0.869339
# Iteration 79, loss = 0.13917586
# Validation score: 0.868974
# Iteration 80, loss = 0.13914095
# Validation score: 0.866522
# Iteration 81, loss = 0.13916438
# Validation score: 0.868476
# Iteration 82, loss = 0.13910480
# Validation score: 0.868214
# Iteration 83, loss = 0.13899938
# Validation score: 0.867404
# Iteration 84, loss = 0.13916203
# Validation score: 0.869842
# Iteration 85, loss = 0.13894782
# Validation score: 0.865466
# Iteration 86, loss = 0.13894547
# Validation score: 0.868225
# Validation score did not improve more than tol=0.000100 for 20 consecutive epochs. Stopping.
#           residue
# 0        1.636447
# 1        1.265190
# 2        1.199434
# 3        1.266280
# 4        1.082711
# ...           ...
# 6519379 -0.215412
# 6519380 -0.914053
# 6519381 -0.069317
# 6519382 -0.088870
# 6519383 -0.791515
#
# [6519384 rows x 1 columns]

# %%
y_pred_mlp[['y','x','time']] = test_set[['y','x','time']]

y_pred_mlp_day = y_pred_mlp[(y_pred_mlp['time'].dt.hour >= 6) & (y_pred_mlp['time'].dt.hour < 18)]
y_pred_mlp_night = y_pred_mlp[(y_pred_mlp['time'].dt.hour < 6) | (y_pred_mlp['time'].dt.hour >= 18)]

print(y_pred_mlp_day)
print(y_pred_mlp_night)
# Out:
#           residue          y         x                time
# 543282   1.801458  50.700043  4.207803 2017-07-01 06:00:00
# 543283   1.684957  50.700110  4.209215 2017-07-01 06:00:00
# 543284   1.617626  50.700184  4.210626 2017-07-01 06:00:00
# 543285   1.642118  50.700256  4.212038 2017-07-01 06:00:00
# 543286   1.623274  50.700325  4.213450 2017-07-01 06:00:00
# ...           ...        ...       ...                 ...
# 5976097 -0.154671  50.986958  4.547782 2017-07-03 17:00:00
# 5976098 -0.419871  50.987026  4.549203 2017-07-03 17:00:00
# 5976099 -0.254030  50.987090  4.550624 2017-07-03 17:00:00
# 5976100 -0.330137  50.987160  4.552045 2017-07-03 17:00:00
# 5976101 -0.396176  50.987225  4.553465 2017-07-03 17:00:00
#
# [3259692 rows x 4 columns]
#           residue          y         x                time
# 0        1.636447  50.700043  4.207803 2017-07-01 00:00:00
# 1        1.265190  50.700110  4.209215 2017-07-01 00:00:00
# 2        1.199434  50.700184  4.210626 2017-07-01 00:00:00
# 3        1.266280  50.700256  4.212038 2017-07-01 00:00:00
# 4        1.082711  50.700325  4.213450 2017-07-01 00:00:00
# ...           ...        ...       ...                 ...
# 6519379 -0.215412  50.986958  4.547782 2017-07-03 23:00:00
# 6519380 -0.914053  50.987026  4.549203 2017-07-03 23:00:00
# 6519381 -0.069317  50.987090  4.550624 2017-07-03 23:00:00
# 6519382 -0.088870  50.987160  4.552045 2017-07-03 23:00:00
# 6519383 -0.791515  50.987225  4.553465 2017-07-03 23:00:00
#
# [3259692 rows x 4 columns]

# %%
model_name = "MLP"
maes_general[model_name], mses_general[model_name], rmses_general[model_name] = calculate_errors(y_test['residue'], y_pred_mlp['residue'])
print("Errors during day:")
maes_day[model_name], mses_day[model_name], rmses_day[model_name] = calculate_errors(y_test_day['residue'], y_pred_mlp_day['residue'])
print("Errors during night:")
maes_night[model_name], mses_night[model_name], rmses_night[model_name] = calculate_errors(y_test_night['residue'], y_pred_mlp_night['residue'])
# Out:
# Mean Absolute Error (MAE): 1.1133299574431335
# Mean Squared Error (MSE): 1.840765665247268
# Root Mean Squared Error (RMSE): 1.3567481952253586
# Errors during day:
# Mean Absolute Error (MAE): 1.210568072612758
# Mean Squared Error (MSE): 2.128860111944982
# Root Mean Squared Error (RMSE): 1.459061380458335
# Errors during night:
# Mean Absolute Error (MAE): 1.0160918422735103
# Mean Squared Error (MSE): 1.5526712185495593
# Root Mean Squared Error (RMSE): 1.2460622851806242

# %%
# sum up y_pred and corrected ERA5 to get the urbclim prediction
urbclim_pred_mlp = pd.DataFrame()

urbclim_pred_mlp['tas'] = y_pred_mlp['residue'] + test_set['t2m_corrected']
urbclim_pred_mlp[['y','x','time']] = test_set[['y','x','time']]

print(urbclim_pred_mlp)

# extract the first timestamp y_pred and plot it
# first_stamp_data = urbclim_pred[(urbclim_pred['time']=="2016-07-01 12:00:00") | (urbclim_pred['time']=="2016-07-01")]
first_stamp_data_mlp = urbclim_pred_mlp[(urbclim_pred_mlp['time']=="2017-07-01 00:00:00")]
tas_min_mlp = first_stamp_data_mlp['tas'].min()
tas_max_mlp = first_stamp_data_mlp['tas'].max()
print("tas min: " ,tas_min_mlp)
print("tas max: " ,tas_max_mlp)
plot_y(first_stamp_data_mlp, 'MLP - tas', 'tas')
# Out:
#                tas          y         x                time
# 0        17.067399  50.700043  4.207803 2017-07-01 00:00:00
# 1        16.696959  50.700110  4.209215 2017-07-01 00:00:00
# 2        16.645480  50.700184  4.210626 2017-07-01 00:00:00
# 3        16.719458  50.700256  4.212038 2017-07-01 00:00:00
# 4        16.509080  50.700325  4.213450 2017-07-01 00:00:00
# ...            ...        ...       ...                 ...
# 6519379  15.189221  50.986958  4.547782 2017-07-03 23:00:00
# 6519380  14.509468  50.987026  4.549203 2017-07-03 23:00:00
# 6519381  15.355627  50.987090  4.550624 2017-07-03 23:00:00
# 6519382  15.327474  50.987160  4.552045 2017-07-03 23:00:00
# 6519383  14.628531  50.987225  4.553465 2017-07-03 23:00:00
#
# [6519384 rows x 4 columns]
# tas min:  15.308156390683719
# tas max:  20.528245294529736

# %%
# 画折线图的函数
def plot_errors(errors):
    for error_name, error_dicts in errors.items():
        plt.figure(figsize=(10, 6))
        for i, error_dict in enumerate(error_dicts):
            cities = list(error_dict.keys())  # 城市名称
            values = list(error_dict.values())  # 对应的数值
            plt.plot(cities, values, marker='o', label=f"{error_name}_set_{i+1}")
        
        plt.title(f"{error_name.upper()} Across Cities")
        plt.xlabel("Cities")
        plt.ylabel(f"{error_name.upper()} Value")
        plt.legend()
        plt.grid()
        plt.show()

# 调用函数
plot_errors(errors)
